# %% [markdown]
# In this notebook, I tried to scrape the webpage I work with in my day job. It seems to be too difficult (site is blocked for scraping)
# in this project2 timeframe, so I will use the data I already have. This would have been just for a scraping exercise.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.arvopaperi.fi/uutiset/tallainen-on-helsingin-porssin-vallan-verkosto-risto-murto-vahtii-viidesosaa-porssin-markkina-arvosta-arja-talma-47-7-miljardia-euroa/c48e0689-2410-4b32-8eb5-a84c53971bdb"

# %%
soup = BeautifulSoup(html)

# %%
http_response = requests.get("https://www.arvopaperi.fi/uutiset/tallainen-on-helsingin-porssin-vallan-verkosto-risto-murto-vahtii-viidesosaa-porssin-markkina-arvosta-arja-talma-47-7-miljardia-euroa/c48e0689-2410-4b32-8eb5-a84c53971bdb")
http_response
# Out:
# <Response [403]>

# %%
html = http_response.text
print(html)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>403 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: X7jhdqksZ7y4L93BldjQRTbBrn4KnuMM2bZifPMJQXm2SAkKOFESqw==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>
